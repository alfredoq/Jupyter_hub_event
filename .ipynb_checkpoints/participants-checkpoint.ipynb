# %%
import functions
import os

# %%
out_dir = "histogramas"
os.makedirs(out_dir, exist_ok=True)

# %%
plots = functions.create_plots_sections()
df = functions.load_excel_file("./registration_data/De_0_a_JupyterHub_en_UNC_Supercómputo_respuestas.xlsx")
for column, title in plots:
        path = os.path.join(out_dir, f"{column}.png")
        print(title)
        functions.plot_histogram(df, column, title=title, save_path=path)
        #print(f"Guardado: {path}")
# Out:
# Distribución por Facultad
# Distribución por Estamento
# Usa Supercómputo
# Conoce Supercómputo
# Habilidad con Jupyter
# Habilidad con Linux
# Habilidad con CLI
